# %%
from util_figures import distribution_data, comparison_ensemble_multi_objective, likelihood_figure, heat_map_figure
import pandas as pd

# %%
dataset_global = pd.read_csv('Data/dataset_odeint_3_inertial.csv')
distribution_data(dataset_global)

# %%
data = {
    'Rayleigh-Plesset': {
        'Dynamical threshold': [0.7763, 0.7875],
        'Mach number': [0.9294, 0.9263],
        'Acoustic emissions': [0.8935, 0.8918],
        'Expansion radius': [0.9694, 0.9696]
    },
    'Keller-Miksis': {
        'Dynamical threshold': [0.8072, 0.8082],
        'Mach number': [0.9015, 0.9018],
        'Acoustic emissions': [0.9158, 0.9117],
        'Expansion radius': [0.9936, 0.9923]
    },
    'Gilmore': {
        'Dynamical threshold': [0.898, 0.8951],
        'Mach number': [0.9678, 0.9676],
        'Acoustic emissions': [0.9274, 0.9214],
        'Expansion radius': [0.9828, 0.983]
    }
}
comparison_ensemble_multi_objective(data)

# %%
dataset = pd.read_csv('Data/dataset_odeint_3_inertial.csv')
# ensemble 
likelihood_figure(dataset, 'initial_radius', 'Ensemble')
# Out:
# Dataset creation ready
# Dataset creation ready
# Dataset creation ready
# Dataset creation ready
# Dataset creation ready
# Dataset creation ready
# Dataset creation ready
# Dataset creation ready
# Dataset creation ready
# Dataset creation ready
# Dataset creation ready
# Dataset creation ready

# %%
dataset = pd.read_csv('Data/dataset_odeint_3_inertial.csv')

heat_map_figure(dataset)
